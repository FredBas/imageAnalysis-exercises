# %% [markdown]
# # Exercise 5 - BLOB Analysis

# %%
from skimage import io, color, morphology
from skimage.util import img_as_float, img_as_ubyte
import matplotlib.pyplot as plt
import numpy as np
from skimage.filters import threshold_otsu
from skimage import segmentation
from skimage import measure
from skimage.color import label2rgb

# %%
def show_comparison(original, modified, modified_name):
    fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(8, 4), sharex=True,
                                   sharey=True)
    ax1.imshow(original)
    ax1.set_title('Original')
    ax1.axis('off')
    ax2.imshow(modified)
    ax2.set_title(modified_name)
    ax2.axis('off')
    io.show()

# %% [markdown]
# ## LEGO Classification

# %% [markdown]
# ### Exercise 1

# %%
in_dir = '../data/'
im_org = io.imread(f'{in_dir}lego_4_small.png')
im_gray = color.rgb2gray(im_org)
thres = threshold_otsu(im_gray)
im_bin = im_gray < thres

show_comparison(im_org, im_bin, 'Binary image')
# Out:
# C:\Users\frede\AppData\Local\Temp\ipykernel_24428\4253354552.py:10: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %% [markdown]
# ### Exercise 2

# %%
im_process = segmentation.clear_border(im_bin)

# %%
show_comparison(im_bin, im_process, 'Binary image (border removed)')
# Out:
# C:\Users\frede\AppData\Local\Temp\ipykernel_24428\4253354552.py:10: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %% [markdown]
# ### Exercise 3

# %%
footprint = morphology.disk(5)
im_process = morphology.binary_closing(im_process, footprint)
im_open = morphology.binary_opening(im_process, footprint)

# %% [markdown]
# ### Exercise 4

# %%
label_img = measure.label(im_open)
n_labels = label_img.max()
print(f"Number of labels: {n_labels}")
# Out:
# Number of labels: 29

# %% [markdown]
# ### Exercise 5

# %%
im_blob = label2rgb(label_img)
show_comparison(im_org, im_blob, 'BLOBS')
# Out:
# C:\Users\frede\AppData\Local\Temp\ipykernel_24428\4253354552.py:10: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %% [markdown]
# ### Exercise 6

# %%
region_props = measure.regionprops(label_img)
areas = np.array([prop.area for prop in region_props])
plt.hist(areas, bins=50)
plt.show()

# %% [markdown]
# ### Exercise 7

# %%
# !python Ex5-BlobAnalysisInteractive.py
# Out:
# Traceback (most recent call last):
#   File "C:\Users\frede\Desktop\uni\5.semester\imageAnalysis\exercises\modul6\ex5-BLOBAnalysis\solutions\Ex5-BlobAnalysisInteractive.py", line 47, in <module>
#     interactive_blobs()
#   File "C:\Users\frede\Desktop\uni\5.semester\imageAnalysis\exercises\modul6\ex5-BLOBAnalysis\solutions\Ex5-BlobAnalysisInteractive.py", line 14, in interactive_blobs
#     img_org = io.imread(in_dir + im_name)
#   File "C:\Users\frede\miniforge3\envs\course02503\lib\site-packages\skimage\_shared\utils.py", line 328, in fixed_func
#     return func(*args, **kwargs)
#   File "C:\Users\frede\miniforge3\envs\course02503\lib\site-packages\skimage\io\_io.py", line 82, in imread
#     img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#   File "C:\Users\frede\miniforge3\envs\course02503\lib\site-packages\skimage\_shared\utils.py", line 538, in wrapped
#     return func(*args, **kwargs)
#   File "C:\Users\frede\miniforge3\envs\course02503\lib\site-packages\skimage\io\manage_plugins.py", line 254, in call_plugin
#     return func(*args, **kwargs)
#   File "C:\Users\frede\miniforge3\envs\course02503\lib\site-packages\skimage\io\_plugins\imageio_plugin.py", line 11, in imread
#     out = np.asarray(imageio_imread(*args, **kwargs))
#   File "C:\Users\frede\miniforge3\envs\course02503\lib\site-packages\imageio\v3.py", line 53, in imread
#     with imopen(uri, "r", **plugin_kwargs) as img_file:
#   File "C:\Users\frede\miniforge3\envs\course02503\lib\site-packages\imageio\core\imopen.py", line 113, in imopen
#     request = Request(uri, io_mode, format_hint=format_hint, extension=extension)
#   File "C:\Users\frede\miniforge3\envs\course02503\lib\site-packages\imageio\core\request.py", line 249, in __init__
#     self._parse_uri(uri)
#   File "C:\Users\frede\miniforge3\envs\course02503\lib\site-packages\imageio\core\request.py", line 409, in _parse_uri
#     raise FileNotFoundError("No such file: '%s'" % fn)
# FileNotFoundError: No such file: 'C:\Users\frede\Desktop\uni\5.semester\imageAnalysis\exercises\modul6\ex5-BLOBAnalysis\solutions\data\lego_4_small.png'

# %% [markdown]
# ## Cell counting

# %%
in_dir = "../data/"
img_org = io.imread(in_dir + 'Sample E2 - U2OS DAPI channel.tiff')
# slice to extract smaller image
img_small = img_org[700:1200, 900:1400]
img_gray = img_as_ubyte(img_small) 
io.imshow(img_gray, vmin=0, vmax=150)
plt.title('DAPI Stained U2OS cell nuclei')
io.show()
# Out:
# C:\Users\frede\AppData\Local\Temp\ipykernel_24428\1237753624.py:6: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(img_gray, vmin=0, vmax=150)
# C:\Users\frede\AppData\Local\Temp\ipykernel_24428\1237753624.py:8: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %%
# avoid bin with value 0 due to the very large number of background pixels
plt.hist(img_gray.ravel(), bins=256, range=(1, 100))
io.show()
# Out:
# C:\Users\frede\AppData\Local\Temp\ipykernel_24428\810072223.py:3: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %% [markdown]
# ### Exercise 8

# %%
thres = threshold_otsu(img_gray)
img_bin = img_gray > thres
show_comparison(img_gray, img_bin, 'binary')
# Out:
# 30
# C:\Users\frede\AppData\Local\Temp\ipykernel_24428\4253354552.py:10: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %% [markdown]
# ### Exercise 9

# %%
img_c_b = segmentation.clear_border(img_bin)

# %%
label_img = measure.label(img_c_b)
image_label_overlay = label2rgb(label_img)
show_comparison(img_gray, image_label_overlay, 'Found BLOBS')
# Out:
# C:\Users\frede\AppData\Local\Temp\ipykernel_24428\4253354552.py:10: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %% [markdown]
# ### Exercise 10

# %%
region_props = measure.regionprops(label_img)
areas = np.array([prop.area for prop in region_props])

# %%
plt.hist(areas, bins=50)
plt.show()

# %% [markdown]
# ### Exercise 11

# %%
min_area = 10 
max_area = 150

# Create a copy of the label_img
label_img_filter = label_img
for region in region_props:
	# Find the areas that do not fit our criteria
	if region.area > max_area or region.area < min_area:
		# set the pixels in the invalid areas to background
		for cords in region.coords:
			label_img_filter[cords[0], cords[1]] = 0
# Create binary image from the filtered label image
i_area = label_img_filter > 0
show_comparison(img_small, i_area, 'Found nuclei based on area')
# Out:
# C:\Users\frede\AppData\Local\Temp\ipykernel_24428\4253354552.py:10: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %% [markdown]
# ### Exercise 12

# %%
perimeters = np.array([prop.perimeter for prop in region_props])

fig, ax = plt.subplots(1,1)
ax.plot(areas, perimeters, '.')
ax.set_xlabel('Areas (px)')
ax.set_ylabel('Perimeter (px)')
plt.show()

# %% [markdown]
# ### Exercise 13

# %%
def circularity(area, perimeter):
    '''
    You may get values larger than 1 because
    we are in a "discrete" (pixels) domain. Check:

    CIRCULARITY OF OBJECTS IN IMAGES, Botterma, M.J. (2000)
    https://core.ac.uk/download/pdf/14946814.pdf
    '''
    f_circ = (4*np.pi*area)/(perimeter**2)
    return f_circ

circs = circularity(areas, perimeters)

# %%
plt.hist(circs, bins=50)
plt.show()

# %%
min_circ = 0.7
min_area = 10 
max_area = 150

# Create a copy of the label_img
label_img_filter = label_img
for region in region_props:
	circ = circularity(region.area, region.perimeter)
	# Find the areas that do not fit our criteria
	if region.area > max_area or region.area < min_area or circ < min_circ:
		# set the pixels in the invalid areas to background
		for cords in region.coords:
			label_img_filter[cords[0], cords[1]] = 0

# Create binary image from the filtered label image
i_area = label_img_filter > 0
show_comparison(img_small, i_area, 'Found nuclei based on area and circularity')
# Out:
# C:\Users\frede\AppData\Local\Temp\ipykernel_24428\4253354552.py:10: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %% [markdown]
# ### Exercise 14

# %%
fig, ax = plt.subplots(1,1)
ax.plot(areas, circs, '.')
ax.set_xlabel('Areas (px)')
ax.set_ylabel('Circularity')
plt.show()

# %%
def cell_counting(img_gray, min_area = 10, max_area = 150, min_circ = 0.7):

    # Binarization
    thres = threshold_otsu(img_gray)
    img_bin = img_gray > thres
    img_c_b = segmentation.clear_border(img_bin)

    # Label image
    label_img = measure.label(img_c_b)

    # Extract properties
    region_props = measure.regionprops(label_img)

    # Number of blobs
    n_nuclei = len(region_props)
    
    # Filter the label image
    label_img_filter = label_img.copy()
    for region in region_props:
        circ = circularity(region.area, region.perimeter)
        # Find the areas that do not fit our criteria
        if region.area > max_area or region.area < min_area or circ < min_circ:
            # set the pixels in the invalid areas to background
            n_nuclei = n_nuclei - 1
            for cords in region.coords:
                label_img_filter[cords[0], cords[1]] = 0

    # Create binary image from the filtered label image
    i_area = label_img_filter > 0

    return i_area, n_nuclei

# %% [markdown]
# ### Exercise 15

# %%
def im2patch(im, patch_size=[256,256]):
    """
    Fancy function to rearrange an image into patches (Not important).
    
    Arguments:
        image: a 2D image, shape (r,c).
        patch size: size of extracted paches.
    Returns:
        patches: a 3D array which in every 3rd dimension has a patch associated 
    """
    
    r,c = im.shape
    s0, s1 = im.strides    
    nrows =r-patch_size[0]+1
    ncols = c-patch_size[1]+1
    shp = patch_size[0],patch_size[1],nrows,ncols
    strd = s0,s1,s0,s1

    out_view = np.lib.stride_tricks.as_strided(im, shape=shp, strides=strd)
    out_view = out_view[:,:,::patch_size[0],::patch_size[1]].reshape(patch_size[0],patch_size[1],-1)
    return out_view

# %%
in_dir = "data/"
img_org = io.imread(in_dir + 'Sample E2 - U2OS DAPI channel.tiff')
img_gray = img_as_ubyte(img_org)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24428\2612067340.py in ?()
#       1 in_dir = "data/"
# ----> 2 img_org = io.imread(in_dir + 'Sample E2 - U2OS DAPI channel.tiff')
#       3 img_gray = img_as_ubyte(img_org)
#
# ~\miniforge3\envs\course02503\lib\site-packages\skimage\_shared\utils.py in ?(*args, **kwargs)
#     324                 elif self.new_name is not None:
#     325                     # Assign old value to new one
#     326                     kwargs[self.new_name] = deprecated_value
#     327
# --> 328             return func(*args, **kwargs)
#
# ~\miniforge3\envs\course02503\lib\site-packages\skimage\io\_io.py in ?(fname, as_gray, plugin, **plugin_args)
#      78         if fname.lower().endswith(('.tiff', '.tif')):
#      79             plugin = 'tifffile'
#      80
#      81     with file_or_url_context(fname) as fname, _hide_plugin_deprecation_warnings():
# ---> 82         img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      83
#      84     if not hasattr(img, 'ndim'):
#      85         return img
#
# ~\miniforge3\envs\course02503\lib\site-packages\skimage\_shared\utils.py in ?(*args, **kwargs)
#     534         @functools.wraps(func)
#     535         def wrapped(*args, **kwargs):
#     536             stacklevel = 1 + self.get_stack_length(func) - stack_rank
#     537             warnings.warn(message, category=FutureWarning, stacklevel=stacklevel)
# --> 538             return func(*args, **kwargs)
#
# ~\miniforge3\envs\course02503\lib\site-packages\skimage\io\manage_plugins.py in ?(kind, *args, **kwargs)
#     250             func = [f for (p, f) in plugin_funcs if p == plugin][0]
#     251         except IndexError:
#     252             raise RuntimeError(f'Could not find the plugin "{plugin}" for {kind}.')
#     253
# --> 254     return func(*args, **kwargs)
#
# ~\miniforge3\envs\course02503\lib\site-packages\skimage\io\_plugins\tifffile_plugin.py in ?(fname, **kwargs)
#      70     """
#      71     if 'img_num' in kwargs:
#      72         kwargs['key'] = kwargs.pop('img_num')
#      73
# ---> 74     return tifffile_imread(fname, **kwargs)
#
# ~\miniforge3\envs\course02503\lib\site-packages\tifffile\tifffile.py in ?(files, selection, aszarr, key, series, level, squeeze, maxworkers, buffersize, mode, name, offset, size, pattern, axesorder, categories, imread, imreadargs, sort, container, chunkshape, chunkdtype, axestiled, ioworkers, chunkmode, fillvalue, zattrs, multiscales, omexml, out, out_inplace, _multifile, _useframes, **kwargs)
#    1203         ):
#    1204             files = files[0]
#    1205
#    1206         if isinstance(files, str) or not isinstance(files, Sequence):
# -> 1207             with TiffFile(
#    1208                 files,
#    1209                 mode=mode,
#    1210                 name=name,
#
# ~\miniforge3\envs\course02503\lib\site-packages\tifffile\tifffile.py in ?(self, file, mode, name, offset, size, omexml, _multifile, _useframes, _parent, **is_flags)
#    4231                 raise ValueError('invalid OME-XML')
#    4232             self._omexml = omexml
#    4233             self.is_ome = True
#    4234
# -> 4235         fh = FileHandle(file, mode=mode, name=name, offset=offset, size=size)
#    4236         self._fh = fh
#    4237         self._multifile = True if _multifile is None else bool(_multifile)
#    4238         self._files = {fh.name: self}
#
# ~\miniforge3\envs\course02503\lib\site-packages\tifffile\tifffile.py in ?(self, file, mode, name, offset, size)
#   14607         self._offset = -1 if offset is None else offset
#   14608         self._size = -1 if size is None else size
#   14609         self._close = True
#   14610         self._lock = NullContext()
# > 14611         self.open()
#   14612         assert self._fh is not None
#
# ~\miniforge3\envs\course02503\lib\site-packages\tifffile\tifffile.py in ?(self)
#   14626             if self._mode not in {'rb', 'r+b', 'wb', 'xb'}:
#   14627                 raise ValueError(f'invalid mode {self._mode}')
#   14628             self._file = os.path.realpath(self._file)
#   14629             self._dir, self._name = os.path.split(self._file)
# > 14630             self._fh = open(self._file, self._mode, encoding=None)
#   14631             self._close = True
#   14632             self._offset = max(0, self._offset)
#   14633         elif isinstance(self._file, FileHandle):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\frede\\Desktop\\uni\\5.semester\\imageAnalysis\\exercises\\modul6\\ex5-BLOBAnalysis\\solutions\\data\\Sample E2 - U2OS DAPI channel.tiff'

# %%
patches = im2patch(img_gray, patch_size=[300,300])
print(f'Number of patches {patches.shape[-1]}')

for idx_patch in range(6):
    patch = patches[:,:,idx_patch]
    filt_label, n_nuclei = cell_counting(patch)
    show_comparison(patch, filt_label, f'Found nuclei: {n_nuclei}')
# Out:
# Number of patches 24

# %% [markdown]
# ### Exercise 16

# %%
img_org = io.imread(in_dir + 'Sample G1 - COS7 cells DAPI channel.tiff')
img_gray = img_as_ubyte(img_org)

patches = im2patch(img_gray, patch_size=[300,300])
print(f'Number of patches {patches.shape[-1]}')

for idx_patch in range(6):
    patch = patches[:,:,idx_patch]
    filt_label, n_nuclei = cell_counting(patch)
    show_comparison(patch, filt_label,  f'Found nuclei: {n_nuclei}')
# Out:
# Number of patches 24
# C:\Users\awias\AppData\Local\Temp\ipykernel_13892\2868012418.py:9: RuntimeWarning: divide by zero encountered in scalar divide
#   f_circ = (4*np.pi*area)/(perimeter**2)

# %% [markdown]
# ### Exercise 17

# %%
def cell_counting_ex17(img_gray, opening_sz = 5, min_area = 10, max_area = 150, min_circ = 0.7):

    # Binarization
    thres = threshold_otsu(img_gray)
    img_bin = img_gray > thres
    img_c_b = segmentation.clear_border(img_bin)
    img_open = morphology.binary_opening(img_c_b, morphology.disk(opening_sz))

    # Label image
    label_img = measure.label(img_open)

    # Extract properties
    region_props = measure.regionprops(label_img)
    
    # Number of blobs
    n_nuclei = len(region_props)
    
    # Filter the label image
    label_img_filter = label_img.copy()
    for region in region_props:
        circ = circularity(region.area, region.perimeter)
        # Find the areas that do not fit our criteria
        if region.area > max_area or region.area < min_area or circ < min_circ:
            n_nuclei = n_nuclei - 1
            # set the pixels in the invalid areas to background
            for cords in region.coords:
                label_img_filter[cords[0], cords[1]] = 0

    # Create binary image from the filtered label image
    i_area = label_img_filter > 0

    return i_area, n_nuclei

# %%
img_org = io.imread(in_dir + 'Sample G1 - COS7 cells DAPI channel.tiff')
img_gray = img_as_ubyte(img_org)

patches = im2patch(img_gray, patch_size=[300,300])
print(f'Number of patches {patches.shape[-1]}')

for idx_patch in range(6):
    patch = patches[:,:,idx_patch]
    filt_label, n_nuclei = cell_counting_ex17(patch, opening_sz = 3)
    show_comparison(patch, filt_label, f'Found nuclei: {n_nuclei}')
# Out:
# Number of patches 24
